# %% [markdown]
# Idea for prediction project taken from https://towardsdatascience.com/5-data-science-projects-in-healthcare-that-will-get-you-hired-81003cadf2f3

# %%
# %matplotlib inline
# basic python
import os
import datetime
import itertools
import pickle
# hide depricated warnings
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
# data handling
import numpy as np
import pandas as pd
# visualization
import matplotlib.pyplot as plt
import seaborn as sns
# machine learning scikit learn
from sklearn import preprocessing, datasets, decomposition, tree, metrics
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_curve, auc
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
# imblearn
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler, SMOTE

# %% [markdown]
# # Stroke Data Set

# %% [markdown]
# dataset source: https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset

# %%
os.chdir("C:/users/akrue/healthdata")

# %%
df = pd.read_csv("C:/users/akrue/healthdata/healthcare-dataset-stroke-data.xls")

# %% [markdown]
# ## Explorative Data Analysis

# %% [markdown]
# My comments are grouped and marked as follows:
#
# <font color='blue'>-> Conclusions from the analysis beginn with a "->" and are marked blue. </font>
#
# <font color='red'>[TODO]: todos start with [TODO]: and are marked red</font>

# %% [markdown]
# ### Exploring the whole dataset: shape, missing values, dtypes

# %% [markdown]
# Getting used to the data set: Are there implausible values, outliers, etc.

# %% [markdown]
# <font color='red'>[TODO]: add text description of columns</font>

# %%
df.shape
# Out:
# (5110, 12)

# %% [markdown]
# <font color='blue'>-> potentially 5110 data points for predicting heart disease</font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %% [markdown]
# <font color='blue'>-> there are *missing values* i, the bmi column -> needs to be removed or imputed later</font>

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %% [markdown]
# <font color='blue'>-> avg_glucose_level, bmi looks to have *outliers* -> my decision: the outlier are not out of the possible range, thus "the data is the data" and I keep the rather extreme values in the analysis </font>

# %%
df.describe(include='object')
# Out:
#         gender ever_married work_type Residence_type smoking_status
# count     5110         5110      5110           5110           5110
# unique       3            2         5              2              4
# top     Female          Yes   Private          Urban   never smoked
# freq      2994         3353      2925           2596           1892

# %%
for col in ['gender','ever_married','work_type','Residence_type','smoking_status']:
    print(df[col].unique())
# Out:
# ['Male' 'Female' 'Other']
# ['Yes' 'No']
# ['Private' 'Self-employed' 'Govt_job' 'children' 'Never_worked']
# ['Urban' 'Rural']
# ['formerly smoked' 'never smoked' 'smokes' 'Unknown']

# %%
replacer = {'gender': {'Other':2,'Male':0,'Female':1},
    'ever_married': {'No':0,'Yes':1},
    'work_type': {'children':0, 'Never_worked':1, 'Private':2, 'Self-employed':3, 'Govt_job':4},
    'Residence_type': {'Rural':0, 'Urban':1},
    'smoking_status': {'never smoked':0, 'Unknown':1, 'formerly smoked':2, 'smokes':3}
}

# %%
df = df.replace(replacer)
for col in ['gender','ever_married','work_type','Residence_type','smoking_status']:
    df[col] = df[col].astype('int64')

# %% [markdown]
# <font color='blue'> -> some of the categorial variables can be interpreted as nominal, e.g. work_type -> my decision: I treat all of them as ordinal so that I can more easily visualize the data and do not add further dimensions like in *one hot encoding*. </font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   int64
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   int64
#  6   work_type          5110 non-null   int64
#  7   Residence_type     5110 non-null   int64
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   int64
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(9)
# memory usage: 479.2 KB

# %%
df.describe()
# Out:
#                  id       gender          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354     0.586301    43.226614      0.097456       0.054012
# std    21161.721625     0.492941    22.612647      0.296607       0.226063
# min       67.000000     0.000000     0.080000      0.000000       0.000000
# 25%    17741.250000     0.000000    25.000000      0.000000       0.000000
# 50%    36932.000000     1.000000    45.000000      0.000000       0.000000
# 75%    54682.000000     1.000000    61.000000      0.000000       0.000000
# max    72940.000000     2.000000    82.000000      1.000000       1.000000
#
#        ever_married    work_type  Residence_type  avg_glucose_level  \
# count   5110.000000  5110.000000     5110.000000        5110.000000
# mean       0.656164     2.144227        0.508023         106.147677
# std        0.475034     1.093648        0.499985          45.283560
# min        0.000000     0.000000        0.000000          55.120000
# 25%        0.000000     2.000000        0.000000          77.245000
# 50%        1.000000     2.000000        1.000000          91.885000
# 75%        1.000000     3.000000        1.000000         114.090000
# max        1.000000     4.000000        1.000000         271.740000
#
#                bmi  smoking_status       stroke
# count  4909.000000     5110.000000  5110.000000
# mean     28.893237        1.111742     0.048728
# std       7.854067        1.071819     0.215320
# min      10.300000        0.000000     0.000000
# 25%      23.500000        0.000000     0.000000
# 50%      28.100000        1.000000     0.000000
# 75%      33.100000        2.000000     0.000000
# max      97.600000        3.000000     1.000000

# %% [markdown]
# Learning: 5110 rows

# %%
len(df['id'])-len(df['id'].drop_duplicates())
# Out:
# 0

# %% [markdown]
# <font color='blue'>-> because each data point has a unique id, there are no multiple data points belonging together somehow as for example when collecting multiple mearurements from the same subjects. This implies that id can be dropped without a loss.</font>

# %%
df = df.drop(columns=['id'])

# %%
assert df.shape[1] == 11

# %%
df[df.isna().any(axis=1)].shape
# Out:
# (201, 11)

# %%
df[df['bmi'].isnull()].shape
# Out:
# (201, 11)

# %% [markdown]
# <font color='blue'>-> missing values are indeed only present in the bmi column (this was already visible from the df.describe())</font>

# %% [markdown]
# ### Univartiat look at the data
# Here I look mainly at the distribution of each variable because we already adressed outliers and missing values

# %%
fig, axs = plt.subplots(1,df.shape[1],figsize=(20,4))
fig.suptitle('box plots of continous variables')
for i, col in enumerate(list(df.columns)):
    axs[i].violinplot(df[col].dropna()) # violin gives impression vor categorials aswell as numericals
    axs[i].set_xlabel(col,rotation=-20)
plt.show()

# %% [markdown]
# <font color='blue'>-> age seems to be covering the whole population</font>
#
# <font color='blue'>->the numerical variables avg_glucose_level and bmi is heavily skewed and might be better described in terms of a gamma distribution or log-normal than a normal distribution</font>
#
# <font color='blue'>->categorialvariables are not evenly destributed for most variables</font>
#
# <font color='blue'>->because units differ between the numeric variables, a standadization would be useful </font>
#
# <font color='blue'>-> bmi is *unimodal* whereas avg_glucose_level is *bimodal*</font>
#
# <font color='blue'>-> only 1 person is neither male nor female -> only one data point in a category is a good reason to remove the data point. </fort>
#
# <font color='blue'>-> the data set is claerly imbalanced for heart_disease and stroke</fort>
#
# <font color='red'>[TODO]: 'unknown' smokeing_status is actually a missing value and should not be encoded as a feature</fort>

# %%
df = df[df['gender'] != 2]

# %%
assert df.shape[0] == 5109 # should contain exactly one datapoint less, just checking here

# %%
p =df["heart_disease"].value_counts()[1]/df.shape[0]*100
f'Only {p:.0f}% of the data points contain heart disease cases'
# Out:
# 'Only 5% of the data points contain heart disease cases'

# %%
dfnan = df[df.isna().any(axis=1)]

# %%
dfnan.iloc[15:20]
# Out:
#      gender   age  hypertension  heart_disease  ever_married  work_type  \
# 81        1  66.0             0              0             1          3
# 84        0  58.0             0              0             1          2
# 105       0  58.0             0              0             1          2
# 112       1  76.0             0              0             1          3
# 124       1  72.0             0              0             1          2
#
#      Residence_type  avg_glucose_level  bmi  smoking_status  stroke
# 81                1             101.45  NaN               1       1
# 84                1              71.20  NaN               1       1
# 105               1              82.30  NaN               3       1
# 112               1             106.41  NaN               2       1
# 124               1             219.91  NaN               1       1

# %% [markdown]
# <font color='blue'>-> these data would be lost if .dropna would be executed. My decision: I replace the values with the median because so that I can keep the data for learning. Median is preferable to the mean as the outliers would draw the mean towards the extreme obersvations.</font>

# %% [markdown]
# ### Bi-variat look at the data

# %%
sns.pairplot(df, hue='heart_disease')
plt.savefig('pair-plot-heart-disease.png',dpi = 300) # normally I would use a vector graphic but the image is too large

# %%
sns.histplot(x='work_type', hue='heart_disease', data=df)
plt.yscale('log') # log scale for better visibility

# %%
sns.histplot(df, x="gender", hue="heart_disease")
plt.yscale('log') # log scale for better visibility

# %%
sns.histplot(df, x="age", y="avg_glucose_level", hue="heart_disease")
# Out:
# <Axes: xlabel='age', ylabel='avg_glucose_level'>

# %% [markdown]
# <font color='blue'>-> avg_glucose_level is bimodal and thus heart disease is clustered amongst the two modes. <font>

# %%
sns.histplot(df, x="age", hue="heart_disease")
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# <font color='blue'>-> the data shows: age is a major risk factor <font>

# %% [markdown]
# <font color='red'>[TODO]: better legend for KDEplots with multiple variables for hue.</font>

# %%
sns.kdeplot(df, x="age", hue=df[["heart_disease","gender"]].apply(tuple, axis=1))
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# <font color='blue'>-> age and gender appear to be a risk factor: The intervall 50 to 85 years is a risk factor (later other health risks may add up) and males appear to have a higher risk in this interval <font>

# %%
sns.histplot(df, x="smoking_status", hue="heart_disease")
# Out:
# <Axes: xlabel='smoking_status', ylabel='Count'>

# %%
fig, axs = plt.subplots(1,2)
sns.histplot(df[df['heart_disease']==1], x="smoking_status",ax=axs[0])
axs[0].set_title('heart_disease==1')
sns.histplot(df[df['heart_disease']==0], x="smoking_status",ax=axs[1])
axs[1].set_title('heart_disease==0')
#fig.autofmt_xdate(rotation=45)
# Out:
# Text(0.5, 1.0, 'heart_disease==0')

# %% [markdown]
# <font color='blue'>-> distribution of smoking_status differs with heart_disease <font>

# %%
fig, axs = plt.subplots(1,2,figsize=(12,4))
sns.histplot(df, x="age", y="bmi", hue="heart_disease", ax=axs[0])
sns.histplot(df, x="age", y="bmi", hue="stroke", ax=axs[1])
# Out:
# <Axes: xlabel='age', ylabel='bmi'>

# %%
df_stroke_and_heart = df[(df['stroke'] == 1) & (df['heart_disease'] == 1)]
df_neither_stroke_nor_heart = df[(df['stroke'] == 0) & (df['heart_disease'] == 0)]
df_either_stroke_or_heart =df[~df.isin(df_stroke_and_heart) & ~df.isin(df_neither_stroke_nor_heart)].dropna(how = 'all')

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = df.corr()
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr,
    cmap=cmap,
    vmax=.3,
    square=True, ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# <font color='red'>-> I have to check whether the correlations measure is apt for categorials.<font>

# %% [markdown]
# ## Preprocessing
# Splitting dataset into relevant numericals and categorials to preprocess them.

# %%
X_numericals = df[['age', 'avg_glucose_level', 'bmi']]
X_categorials = df[['gender', 'hypertension', 'ever_married', 'work_type', 'Residence_type', 'smoking_status', 'stroke']]
y = df['heart_disease']

# %%
file = open('y', 'wb')
pickle.dump(y,file)

# %% [markdown]
# ## Numericals

# %%
# Deal with missing values

# %%
X_numericals[X_numericals.isna().any(axis=1)].shape
# Out:
# (201, 3)

# %%
imp_median = SimpleImputer(missing_values=np.nan, strategy='median')
imp_median.fit(X_numericals)
X_numericals_imp = imp_median.transform(X_numericals)

# %%
# Normalization because units differ
scaler = preprocessing.StandardScaler().fit(X_numericals_imp)
X_numericals_imp_scaled = scaler.transform(X_numericals_imp)

# %%
file = open('X_numericals_imp_scaled', 'wb')
pickle.dump(X_numericals_imp_scaled,file)

# %%
test = pd.DataFrame(X_numericals_imp_scaled)

# %%
np.isnan(np.sum(X_numericals_imp_scaled))
# Out:
# False

# %%
# normally distributed? 
test.hist()
# Out:
# array([[<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>],
#        [<Axes: title={'center': '2'}>, <Axes: >]], dtype=object)

# %%
np.random.seed(42)

pca_model = decomposition.PCA(n_components=2).fit(X_numericals_imp)
explained_var = pca_model.explained_variance_ratio_*100
scores = pd.DataFrame(pca_model.transform(X_numericals_imp), columns=['PC1','PC2'])
scores['heart_disease'] = df['heart_disease']

#sns.set(rc={'figure.figsize':(7, 7)})
sns.scatterplot(x='PC1', y='PC2', data=scores,
               hue='heart_disease')

plt.xlabel('PC1'.format(exp_var=explained_var[0]))
plt.ylabel('PC2'.format(exp_var=explained_var[1]))
plt.show()

# %% [markdown]
# <font color='blue'>-> heart_disease seems not linearly separable<font>

# %% [markdown]
# ### Combine numericals and categorial variables to a single X for ML

# %%
X_numericals_imp_scaled.shape
# Out:
# (5109, 3)

# %%
X_categorials.shape
# Out:
# (5109, 7)

# %%
X = np.concatenate((X_numericals_imp_scaled, X_categorials), axis=1)

# %%
X.shape
# Out:
# (5109, 10)

# %%
y.shape
# Out:
# (5109,)

# %% [markdown]
# ### Random undersampling, splitting training and test dataset

# %%
def make_random_undersampleling(X, y, sampling_strategy = 1, random_state=None):
    binary_mask = y.isin([0, 1])
    binary_y = y[binary_mask]
    binary_X = X[binary_mask]
    rus = RandomUnderSampler(sampling_strategy=sampling_strategy, random_state=random_state)
    X_res, y_res = rus.fit_resample(binary_X, binary_y)
    return X_res, y_res

# %%
def make_random_oversampleling(X, y, random_state=None):
    ros = RandomOverSampler(random_state=random_state)
    X_res, y_res = ros.fit_resample(X, y)
    return X_res, y_res

# %%
def make_SMOTE_oversampleling(X, y):
    X_res, y_res = SMOTE().fit_resample(X, y)
    return X_res, y_res

# %%
X_res, y_res = make_random_undersampleling(X,y,sampling_strategy=1,random_state=42)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, train_size=0.3, random_state=42)

# %% [markdown]
# ## Training of an ML model and evaluation vs base model

# %% [markdown]
# <font color='red'>[TODO]: This ML part and the following model selection should be combined better: E.g. all metrics for all models, parameter tuning could be added etc. Because of my limited time, this must suffice for a preliminary result<font>

# %%
clf = SVC(kernel="linear", C=0.025, random_state=42)

# %%
clf.fit(X_train,y_train)
# Out:
# SVC(C=0.025, kernel='linear', random_state=42)

# %%
y_pred_svm = clf.predict(X_test)

# %%
conf_matrix = metrics.confusion_matrix(y_test, y_pred_svm)

# %%
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in conf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in conf_matrix.flatten()/np.sum(conf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(conf_matrix, annot=labels, fmt='', cmap='Blues')
# Out:
# <Axes: >

# %%
acc = accuracy_score(y_test,y_pred_svm)
prec = precision_score(y_test,y_pred_svm)
rec = recall_score(y_test,y_pred_svm)
f1 = f1_score(y_test,y_pred_svm)
print(f'accuracy: {acc:.2f}\nprecision: {prec:.2f}\nrecall {rec:.2f}\nf1: {f1:.2f}')
# Out:
# accuracy: 0.79
# precision: 0.74
# recall 0.86
# f1: 0.80

# %%
y_pred_svm_all = clf.predict(X)
print(accuracy_score(y,y_pred_svm_all))
print(precision_score(y,y_pred_svm_all))
print(recall_score(y,y_pred_svm_all))
print(f1_score(y,y_pred_svm_all))
# Out:
# 0.718340183989039
# 0.14434250764525994
# 0.855072463768116
# 0.2469911041339613

# %%
fpr, tpr, thresholds = roc_curve(y, y_pred_svm_all)
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, label='ROC curve (area = %0.3f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')  # random predictions curve
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate or (1 - Specifity)')
plt.ylabel('True Positive Rate or (Sensitivity)')
plt.legend(loc="lower right")

# %%
scoring = {'acc': 'accuracy',
           'prec_macro': 'precision_macro',
           'rec_micro': 'recall_macro'}

# %%
score = cross_validate(clf, X_res, y_res, scoring=scoring, cv=5, return_train_score=True)

# %%
for item in score:
    mean = np.mean(score[item])
    print(f'{item} mean = {mean:.2f}')
# Out:
# fit_time mean = 0.00
# score_time mean = 0.00
# test_acc mean = 0.78
# train_acc mean = 0.79
# test_prec_macro mean = 0.79
# train_prec_macro mean = 0.80
# test_rec_micro mean = 0.78
# train_rec_micro mean = 0.79

# %%
score = cross_validate(clf, X, y, scoring=scoring, cv=5, return_train_score=True)
for item in score:
    mean = np.mean(score[item])
    print(f'{item} mean = {mean:.2f}')
# Out:
# C:\Users\akrue\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\akrue\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\akrue\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\akrue\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\akrue\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\akrue\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\akrue\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\akrue\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# fit_time mean = 0.05
# score_time mean = 0.02
# test_acc mean = 0.95
# train_acc mean = 0.95
# test_prec_macro mean = 0.47
# train_prec_macro mean = 0.47
# test_rec_micro mean = 0.50
# train_rec_micro mean = 0.50
# C:\Users\akrue\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\akrue\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# <font color='blue'>-> the base line model without under or oversampling is clearly worse. With a precision and recall of .8 the initial SVM offers a meaningful classifikation in comparision to the base model.<font>

# %% [markdown]
# ### Model selection

# %% [markdown]
# <font color='red'> [TODO]: For a first evaluation, I took a set of classifiers from the sklearn docs. The choice of classifiers could be improved. Also, hyperparameters could be optimized. <font>

# %%
names = [
    "Nearest Neighbors",
    "Linear SVM",
    "RBF SVM",
    "Gaussian Process",
    "Decision Tree",
    "Random Forest",
    "Neural Net",
    "AdaBoost",
    "Naive Bayes",
    "QDA",
]

classifiers = [
    KNeighborsClassifier(3),
    SVC(kernel="linear", C=0.025, random_state=42),
    SVC(gamma=2, C=1, random_state=42),
    GaussianProcessClassifier(1.0 * RBF(1.0), random_state=42),
    DecisionTreeClassifier(max_depth=5, random_state=42),
    RandomForestClassifier(
        max_depth=5, n_estimators=10, max_features=1, random_state=42
    ),
    MLPClassifier(alpha=1, max_iter=1000, random_state=42),
    AdaBoostClassifier(random_state=42),
    GaussianNB(),
    QuadraticDiscriminantAnalysis(),
]

# %% [markdown]
# The quality of the classifier may depend on the chosen undersample, thus I draw 10 different undersamples and uns the mean as an estimator of the quality of this approach

# %%
# iterate over classifiers
scores = []
max_undersamples = 10
with open("logfile.txt", "a") as f:
    print(datetime.datetime.now(), file=f)
    for i in range(max_undersamples):
        print("undersample " + str(i) +" / " + str(max_undersamples))
        cur_undersample_scores = []
        X_res, y_res = make_random_undersampleling(X,y)
        for name, clf in zip(names, classifiers):
            cur_undersample_scores
            print(name+ 'scores ', file=f)
            score = cross_val_score(clf, X_res, y_res, scoring='f1', cv=10, n_jobs = -1)
            print(str(score) + " mean: " + str(np.mean(score)), file=f)
            cur_undersample_scores.append(np.mean(score))
        scores.append(cur_undersample_scores)
# Out:
# undersample 0 / 10
# undersample 1 / 10
# undersample 2 / 10
# undersample 3 / 10
# undersample 4 / 10
# undersample 5 / 10
# undersample 6 / 10
# undersample 7 / 10
# undersample 8 / 10
# undersample 9 / 10

# %%
pd.DataFrame(scores,columns=names).describe()
# Out:
#        Nearest Neighbors  Linear SVM    RBF SVM  Gaussian Process  \
# count          10.000000   10.000000  10.000000         10.000000
# mean            0.740988    0.805159   0.744344          0.793043
# std             0.024440    0.008049   0.022879          0.011142
# min             0.706770    0.793810   0.706293          0.776666
# 25%             0.721915    0.800171   0.725220          0.782732
# 50%             0.744796    0.804404   0.748853          0.795049
# 75%             0.756899    0.810585   0.761359          0.802713
# max             0.772351    0.820119   0.774863          0.806309
#
#        Decision Tree  Random Forest  Neural Net   AdaBoost  Naive Bayes  \
# count      10.000000      10.000000   10.000000  10.000000    10.000000
# mean        0.767788       0.774532    0.791408   0.776548     0.770542
# std         0.022724       0.015711    0.011963   0.013564     0.011581
# min         0.724896       0.745165    0.773172   0.748887     0.743154
# 25%         0.752330       0.772227    0.782936   0.769202     0.765959
# 50%         0.769650       0.775888    0.790827   0.778871     0.773083
# 75%         0.785037       0.787317    0.800461   0.783556     0.777725
# max         0.794482       0.792239    0.811091   0.795965     0.783432
#
#              QDA
# count  10.000000
# mean    0.771902
# std     0.013131
# min     0.754836
# 25%     0.762351
# 50%     0.770052
# 75%     0.779876
# max     0.791815

# %%
# iterate over classifiers
scores = []
max_undersamples = 10
with open("logfile.txt", "a") as f:
    print(datetime.datetime.now(), file=f)
    for i in range(max_undersamples):
        print("undersample " + str(i) +" / " + str(max_undersamples))
        cur_undersample_scores = []
        X_res, y_res = make_random_undersampleling(X,y)
        for name, clf in zip(names, classifiers):
            cur_undersample_scores
            print(name+ 'scores ', file=f)
            score = cross_val_score(clf, X_res, y_res, scoring='recall', cv=10, n_jobs = -1)
            print(str(score) + " mean: " + str(np.mean(score)), file=f)
            cur_undersample_scores.append(np.mean(score))
        scores.append(cur_undersample_scores)
# Out:
# undersample 0 / 10
# undersample 1 / 10
# undersample 2 / 10
# undersample 3 / 10
# undersample 4 / 10
# undersample 5 / 10
# undersample 6 / 10
# undersample 7 / 10
# undersample 8 / 10
# undersample 9 / 10

# %%
pd.DataFrame(scores,columns=names).describe()
# Out:
#        Nearest Neighbors  Linear SVM    RBF SVM  Gaussian Process  \
# count          10.000000   10.000000  10.000000         10.000000
# mean            0.767791    0.873069   0.854775          0.827302
# std             0.024241    0.007606   0.022404          0.008954
# min             0.746296    0.862302   0.815079          0.818915
# 25%             0.750926    0.866766   0.841997          0.819874
# 50%             0.758466    0.873082   0.857937          0.826257
# 75%             0.777778    0.876687   0.870205          0.831647
# max             0.825794    0.887434   0.887698          0.847619
#
#        Decision Tree  Random Forest  Neural Net   AdaBoost  Naive Bayes  \
# count      10.000000      10.000000   10.000000  10.000000    10.000000
# mean        0.798280       0.842421    0.829894   0.797183     0.785370
# std         0.047918       0.017682    0.013271   0.024116     0.020055
# min         0.727910       0.814550    0.808333   0.757407     0.753836
# 25%         0.763459       0.828935    0.820337   0.777811     0.770040
# 50%         0.800397       0.846098    0.833399   0.806151     0.788228
# 75%         0.825265       0.856812    0.837136   0.811872     0.801025
# max         0.873148       0.862434    0.851587   0.826190     0.811905
#
#              QDA
# count  10.000000
# mean    0.779960
# std     0.026179
# min     0.753571
# 25%     0.760450
# 50%     0.766204
# 75%     0.804134
# max     0.822487

# %% [markdown]
# ### Model comparison with undersampling

# %%
random_state = 42
X_res, y_res = make_random_undersampleling(X,y,sampling_strategy=0.4,random_state=random_state)
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, train_size=0.3, random_state=42)
for name, clf in zip(names, classifiers):
    print(name)
    model = clf.fit(X_train, y_train)
    y_pred_tree = clf.predict(X_test)
    acc = accuracy_score(y_test,y_pred_tree)
    prec = precision_score(y_test,y_pred_tree)
    rec = recall_score(y_test,y_pred_tree)
    f1 = f1_score(y_test,y_pred_tree)
    print(f'\tfor test dataset:\n\taccuracy: {acc:.2f}\n\tprecision: {prec:.2f}\n\trecall {rec:.2f}\n\tf1: {f1:.2f}')
    #y_pred_tree_all = clf.predict(X)
    #acc_all = accuracy_score(y,y_pred_tree_all)
    #prec_all = precision_score(y,y_pred_tree_all)
    #rec_all = recall_score(y,y_pred_tree_all)
    #f1_all = f1_score(y,y_pred_tree_all)
    #print(f'\tfor whole dataset:\n\taccuracy: {acc_all:.2f}\n\tprecision: {prec_all:.2f}\n\trecall {rec_all:.2f}\n\tf1: {f1_all:.2f}')
# Out:
# Nearest Neighbors
# 	for test dataset:
# 	accuracy: 0.77
# 	precision: 0.57
# 	recall 0.57
# 	f1: 0.57
# Linear SVM
# 	for test dataset:
# 	accuracy: 0.78
# 	precision: 0.63
# 	recall 0.45
# 	f1: 0.52
# RBF SVM
# 	for test dataset:
# 	accuracy: 0.74
# 	precision: 0.55
# 	recall 0.09
# 	f1: 0.15
# Gaussian Process
# 	for test dataset:
# 	accuracy: 0.79
# 	precision: 0.60
# 	recall 0.59
# 	f1: 0.60
# Decision Tree
# 	for test dataset:
# 	accuracy: 0.76
# 	precision: 0.55
# 	recall 0.53
# 	f1: 0.54
# Random Forest
# 	for test dataset:
# 	accuracy: 0.78
# 	precision: 0.65
# 	recall 0.36
# 	f1: 0.46
# Neural Net
# 	for test dataset:
# 	accuracy: 0.79
# 	precision: 0.61
# 	recall 0.59
# 	f1: 0.60
# AdaBoost
# 	for test dataset:
# 	accuracy: 0.74
# 	precision: 0.53
# 	recall 0.48
# 	f1: 0.50
# Naive Bayes
# 	for test dataset:
# 	accuracy: 0.75
# 	precision: 0.53
# 	recall 0.71
# 	f1: 0.60
# QDA
# 	for test dataset:
# 	accuracy: 0.76
# 	precision: 0.54
# 	recall 0.72
# 	f1: 0.62

# %% [markdown]
# ### Model comparison with random oversampling

# %%
random_state = 42
X_res, y_res = make_random_oversampleling(X,y,random_state=random_state)
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, train_size=0.3, random_state=42)
for name, clf in zip(names, classifiers):
    print(name)
    model = clf.fit(X_train, y_train)
    y_pred_tree = clf.predict(X_test)
    acc = accuracy_score(y_test,y_pred_tree)
    prec = precision_score(y_test,y_pred_tree)
    rec = recall_score(y_test,y_pred_tree)
    f1 = f1_score(y_test,y_pred_tree)
    print(f'\tfor test dataset:\n\taccuracy: {acc:.2f}\n\tprecision: {prec:.2f}\n\trecall {rec:.2f}\n\tf1: {f1:.2f}')
    #y_pred_tree_all = clf.predict(X)
    #acc_all = accuracy_score(y,y_pred_tree_all)
    #prec_all = precision_score(y,y_pred_tree_all)
    #rec_all = recall_score(y,y_pred_tree_all)
    #f1_all = f1_score(y,y_pred_tree_all)
    #print(f'\tfor whole dataset:\n\taccuracy: {acc_all:.2f}\n\tprecision: {prec_all:.2f}\n\trecall {rec_all:.2f}\n\tf1: {f1_all:.2f}')
# Out:
# Nearest Neighbors
# 	for test dataset:
# 	accuracy: 0.89
# 	precision: 0.83
# 	recall 0.99
# 	f1: 0.90
# Linear SVM
# 	for test dataset:
# 	accuracy: 0.79
# 	precision: 0.75
# 	recall 0.87
# 	f1: 0.80
# RBF SVM
# 	for test dataset:
# 	accuracy: 0.96
# 	precision: 0.93
# 	recall 0.99
# 	f1: 0.96
# Gaussian Process
# 	for test dataset:
# 	accuracy: 0.93
# 	precision: 0.88
# 	recall 1.00
# 	f1: 0.93
# Decision Tree
# 	for test dataset:
# 	accuracy: 0.81
# 	precision: 0.75
# 	recall 0.93
# 	f1: 0.83
# Random Forest
# 	for test dataset:
# 	accuracy: 0.79
# 	precision: 0.73
# 	recall 0.93
# 	f1: 0.82
# Neural Net
# 	for test dataset:
# 	accuracy: 0.81
# 	precision: 0.77
# 	recall 0.89
# 	f1: 0.82
# AdaBoost
# 	for test dataset:
# 	accuracy: 0.80
# 	precision: 0.76
# 	recall 0.87
# 	f1: 0.81
# Naive Bayes
# 	for test dataset:
# 	accuracy: 0.77
# 	precision: 0.75
# 	recall 0.81
# 	f1: 0.78
# QDA
# 	for test dataset:
# 	accuracy: 0.79
# 	precision: 0.76
# 	recall 0.82
# 	f1: 0.79

# %% [markdown]
# ### Model comparison with SMOTE oversampling

# %%
random_state = 42
X_res, y_res = make_SMOTE_oversampleling(X,y)
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, train_size=0.3, random_state=42)
for name, clf in zip(names, classifiers):
    print(name)
    model = clf.fit(X_train, y_train)
    y_pred_tree = clf.predict(X_test)
    acc = accuracy_score(y_test,y_pred_tree)
    prec = precision_score(y_test,y_pred_tree)
    rec = recall_score(y_test,y_pred_tree)
    f1 = f1_score(y_test,y_pred_tree)
    print(f'\tfor test dataset:\n\taccuracy: {acc:.2f}\n\tprecision: {prec:.2f}\n\trecall {rec:.2f}\n\tf1: {f1:.2f}')
    #y_pred_tree_all = clf.predict(X)
    #acc_all = accuracy_score(y,y_pred_tree_all)
    #prec_all = precision_score(y,y_pred_tree_all)
    #rec_all = recall_score(y,y_pred_tree_all)
    #f1_all = f1_score(y,y_pred_tree_all)
    #print(f'\tfor whole dataset:\n\taccuracy: {acc_all:.2f}\n\tprecision: {prec_all:.2f}\n\trecall {rec_all:.2f}\n\tf1: {f1_all:.2f}')
# Out:
# Nearest Neighbors
# 	for test dataset:
# 	accuracy: 0.88
# 	precision: 0.81
# 	recall 0.99
# 	f1: 0.89
# Linear SVM
# 	for test dataset:
# 	accuracy: 0.81
# 	precision: 0.76
# 	recall 0.90
# 	f1: 0.82
# RBF SVM
# 	for test dataset:
# 	accuracy: 0.95
# 	precision: 0.91
# 	recall 0.98
# 	f1: 0.95
# Gaussian Process
# 	for test dataset:
# 	accuracy: 0.92
# 	precision: 0.87
# 	recall 0.98
# 	f1: 0.92
# Decision Tree
# 	for test dataset:
# 	accuracy: 0.83
# 	precision: 0.80
# 	recall 0.88
# 	f1: 0.84
# Random Forest
# 	for test dataset:
# 	accuracy: 0.85
# 	precision: 0.80
# 	recall 0.93
# 	f1: 0.86
# Neural Net
# 	for test dataset:
# 	accuracy: 0.83
# 	precision: 0.77
# 	recall 0.92
# 	f1: 0.84
# AdaBoost
# 	for test dataset:
# 	accuracy: 0.86
# 	precision: 0.83
# 	recall 0.90
# 	f1: 0.86
# Naive Bayes
# 	for test dataset:
# 	accuracy: 0.79
# 	precision: 0.74
# 	recall 0.88
# 	f1: 0.80
# QDA
# 	for test dataset:
# 	accuracy: 0.79
# 	precision: 0.76
# 	recall 0.86
# 	f1: 0.81

# %% [markdown]
# ### Explainable classifier

# %%
for treedepth in range(1,5):
    random_state = 42
    X_res, y_res = make_SMOTE_oversampleling(X,y)
    X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, train_size=0.3, random_state=42)
    clf = DecisionTreeClassifier(random_state=random_state,max_depth=treedepth)
    model = clf.fit(X_train, y_train)
    y_pred_tree = clf.predict(X_test)
    acc = accuracy_score(y_test,y_pred_tree)
    prec = precision_score(y_test,y_pred_tree)
    rec = recall_score(y_test,y_pred_tree)
    f1 = f1_score(y_test,y_pred_tree)
    print(f'for depth = {treedepth}:\n\taccuracy: {acc:.2f}\n\tprecision: {prec:.2f}\n\trecall {rec:.2f}\n\tf1: {f1:.2f}')
    text_representation = tree.export_text(clf)
    with open(f'visualization-tree-depth{treedepth}.txt','w') as f:
        print('Decision Tree Classifier visualization for undersample and classifier with random_state = '+ str(random_state),file=f)
        print(f'for depth = {treedepth}:\n\taccuracy: {acc:.2f}\n\tprecision: {prec:.2f}\n\trecall {rec:.2f}\n\tf1: {f1:.2f}',file=f)
        print(text_representation,file=f)
# Out:
# for depth = 1:
# 	accuracy: 0.79
# 	precision: 0.71
# 	recall 0.95
# 	f1: 0.81
# for depth = 2:
# 	accuracy: 0.79
# 	precision: 0.72
# 	recall 0.95
# 	f1: 0.82
# for depth = 3:
# 	accuracy: 0.81
# 	precision: 0.78
# 	recall 0.85
# 	f1: 0.81
# for depth = 4:
# 	accuracy: 0.82
# 	precision: 0.77
# 	recall 0.92
# 	f1: 0.84

# %% [markdown]
# # Conclusion

# %% [markdown]
# The goal of predicting the binary variable heart disease from the given data set ist best adressed by the RFB SVM. The recall score .98 and good f1 score 0.95 describe good performance on the test data set.
#
# Importantly, the handling of the imbalance in the data set affects performance severely. Undersampling has proven suboptimal and random oversampling performs better but is still worse than SMOTE.
#
# Also, hyperparameter tuning could improve the result.

# %% [markdown]
# # Bayesian Analysis of Heart Failure

# %% [markdown]
# <font color='red'> [TODO]: Also, Bayesian analysis can predict heart disease, e.g. with a logistic regression. Unfortunately, I could not get the pymc framework working under windows. The older pymc3 might be an alter <font>

# %% [markdown]
# https://www.kaggle.com/code/monogenea/bayesian-approach-to-heart-failure-prediction
